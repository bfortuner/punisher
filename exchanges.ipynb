# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
from punisher.common import *
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
exchange = load_exchange(c.BINANCE)

# %% [markdown]
# # Testing Order responses CAREFUL LIVE TRADING

# %%
base = c.XRP
quote = c.BTC
asset = Asset(base, quote)
ticker = exchange.fetch_ticker(asset)
pprint(ticker)
price = ticker['bid']

# currently not working as intended... still doesnt provide quantity that meets binance requirements
def min_quantity_needed(min_coin_quantity, price):
    return math.ceil(min_coin_quantity / price)

print("\nPRICE of {} : ".format(base) + str(price))
print("quantity >= {} {}".format(min_quantity_needed(c.MIN_BTC, price), base))
print("Minimum BTC cost = quantity * price = {} BTC".format(price*(.001/price)))
print("Rules : Cost must be > 0.001 BTC or 0.01 ETH or 1 BNB or 1 USDT")
# Out:
# {'ask': 0.0001023,
#  'average': None,
#  'baseVolume': 166119490.0,
#  'bid': 0.00010221,
#  'change': -15.823,
#  'close': 0.00012159,
#  'datetime': '2018-01-17T05:36:50.208Z',
#  'first': None,
#  'high': 0.0001237,
#  'info': {'askPrice': '0.00010230',
#           'askQty': '4721.00000000',
#           'bidPrice': '0.00010221',
#           'bidQty': '323.00000000',
#           'closeTime': 1516167410208,
#           'count': 292496,
#           'firstId': 9486338,
#           'highPrice': '0.00012370',
#           'lastId': 9778833,
#           'lastPrice': '0.00010230',
#           'lastQty': '3367.00000000',
#           'lowPrice': '0.00008400',
#           'openPrice': '0.00012153',
#           'openTime': 1516081010208,
#           'prevClosePrice': '0.00012159',
#           'priceChange': '-0.00001923',
#           'priceChangePercent': '-15.823',
#           'quoteVolume': '17588.17438919',
#           'symbol': 'XRPBTC',
#           'volume': '166119490.00000000',
#           'weightedAvgPrice': '0.00010588'},
#  'last': 0.0001023,
#  'low': 8.4e-05,
#  'open': 0.00012153,
#  'percentage': None,
#  'quoteVolume': 17588.17438919,
#  'symbol': 'XRP/BTC',
#  'timestamp': 1516167410208,
#  'vwap': 0.00010588}
#
# PRICE of XRP : 0.00010221
# quantity >= 10 XRP
# Minimum BTC cost = quantity * price = 0.001 BTC
# Rules : Cost must be > 0.001 BTC or 0.01 ETH or 1 BNB or 1 USDT

# %%
# Example insufficient amount * price

res = exchange.create_limit_buy_order(asset, 1, price)
pprint(res)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# ~/anaconda3/envs/py36/lib/python3.6/site-packages/ccxt/base/exchange.py in fetch(self, url, method, headers, body)
#     345             self.last_http_response = response.text
# --> 346             response.raise_for_status()
#     347
#
# ~/anaconda3/envs/py36/lib/python3.6/site-packages/requests/models.py in raise_for_status(self)
#     934         if http_error_msg:
# --> 935             raise HTTPError(http_error_msg, response=self)
#     936
#
# HTTPError: 400 Client Error: Bad Request for url: https://api.binance.com/api/v3/order
#
# During handling of the above exception, another exception occurred:
#
# InvalidOrder                              Traceback (most recent call last)
# <ipython-input-17-f5a7db8eb453> in <module>()
#       1 # Example insufficient amount * price
#       2
# ----> 3 res = exchange.create_limit_buy_order(asset, 1, price)
#       4 pprint(res)
#
# ~/code/public/punisher/punisher/exchanges/exchange.py in create_limit_buy_order(self, asset, quantity, price, params)
#     130         params = self.get_default_params_if_none(params)
#     131         return self.client.create_limit_buy_order(
# --> 132             asset.symbol, quantity, price, params)
#     133
#     134     def create_limit_sell_order(self, asset, quantity, price, params=None):
#
# ~/anaconda3/envs/py36/lib/python3.6/site-packages/ccxt/base/exchange.py in create_limit_buy_order(self, symbol, *args)
#     999
#    1000     def create_limit_buy_order(self, symbol, *args):
# -> 1001         return self.create_order(symbol, 'limit', 'buy', *args)
#    1002
#    1003     def create_limit_sell_order(self, symbol, *args):
#
# ~/anaconda3/envs/py36/lib/python3.6/site-packages/ccxt/binance.py in create_order(self, symbol, type, side, amount, price, params)
#     543                 'timeInForce': 'GTC',  # 'GTC' = Good To Cancel(default), 'IOC' = Immediate Or Cancel
#     544             })
# --> 545         response = self.privatePostOrder(self.extend(order, params))
#     546         return {
#     547             'info': response,
#
# ~/anaconda3/envs/py36/lib/python3.6/site-packages/ccxt/base/exchange.py in request(self, path, api, method, params, headers, body)
#     294
#     295     def request(self, path, api='public', method='GET', params={}, headers=None, body=None):
# --> 296         return self.fetch2(path, api, method, params, headers, body)
#     297
#     298     @staticmethod
#
# ~/anaconda3/envs/py36/lib/python3.6/site-packages/ccxt/base/exchange.py in fetch2(self, path, api, method, params, headers, body)
#     291         self.lastRestRequestTimestamp = self.milliseconds()
#     292         request = self.sign(path, api, method, params, headers, body)
# --> 293         return self.fetch(request['url'], request['method'], request['headers'], request['body'])
#     294
#     295     def request(self, path, api='public', method='GET', params={}, headers=None, body=None):
#
# ~/anaconda3/envs/py36/lib/python3.6/site-packages/ccxt/base/exchange.py in fetch(self, url, method, headers, body)
#     356
#     357         except HTTPError as e:
# --> 358             self.handle_errors(response.status_code, response.reason, url, method, None, self.last_http_response)
#     359             self.handle_rest_errors(e, response.status_code, self.last_http_response, url, method)
#     360             self.raise_error(ExchangeError, url, method, e, self.last_http_response)
#
# ~/anaconda3/envs/py36/lib/python3.6/site-packages/ccxt/binance.py in handle_errors(self, code, reason, url, method, headers, body)
#     689                 raise DDoSProtection(self.id + ' ' + str(code) + ' ' + reason + ' ' + body)
#     690             if body.find('MIN_NOTIONAL') >= 0:
# --> 691                 raise InvalidOrder(self.id + ' order cost = amount * price should be >(0.001 BTC or 0.01 ETH or 1 BNB or 1 USDT)' + body)
#     692             if body.find('LOT_SIZE') >= 0:
#     693                 raise InvalidOrder(self.id + ' order amount should be evenly divisible by lot size, use self.amount_to_lots(symbol, amount) ' + body)
#
# InvalidOrder: binance order cost = amount * price should be >(0.001 BTC or 0.01 ETH or 1 BNB or 1 USDT){"code":-1013,"msg":"Filter failure: MIN_NOTIONAL"}

# %%
# Example sufficient amount * price
res = exchange.create_limit_buy_order(asset, 20, price)
pprint(res)
# Out:
# 0.0010221
# {'id': '19121540',
#  'info': {'clientOrderId': 'XcRu3uVEd3fg4V657P6Tq2',
#           'executedQty': '0.00000000',
#           'orderId': 19121540,
#           'origQty': '20.00000000',
#           'price': '0.00010221',
#           'side': 'BUY',
#           'status': 'NEW',
#           'symbol': 'XRPBTC',
#           'timeInForce': 'GTC',
#           'transactTime': 1516167604841,
#           'type': 'LIMIT'}}

# %%
# Example limit sell NOT CURRENTLY WORKING
# res = exchange.create_limit_sell_order(asset, 20, price)
# pprint(res)
# Out:
# XRP/BTC 20 0.00010221
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-27-2e87d40926ec> in <module>()
#       1 # Example sufficient amount * price
# ----> 2 res = exchange.create_limit_sell_order(asset, 20, price)
#       3 pprint(res)
#
# ~/code/public/punisher/punisher/exchanges/exchange.py in create_limit_sell_order(self, asset, quantity, price, params)
#     135         print(asset.symbol, quantity, price)
#     136         return self.client.create_limit_sell_order(
# --> 137             asset.symbol, quantity, price, params)
#     138
#     139     def create_market_buy_order(self, asset, quantity, params=None):
#
# ~/anaconda3/envs/py36/lib/python3.6/site-packages/ccxt/base/exchange.py in create_limit_sell_order(self, symbol, *args)
#    1002
#    1003     def create_limit_sell_order(self, symbol, *args):
# -> 1004         return self.create_order(symbol, 'limit', 'sell', *args)
#    1005
#    1006     def create_market_buy_order(self, symbol, amount, params={}):
#
# ~/anaconda3/envs/py36/lib/python3.6/site-packages/ccxt/binance.py in create_order(self, symbol, type, side, amount, price, params)
#     543                 'timeInForce': 'GTC',  # 'GTC' = Good To Cancel(default), 'IOC' = Immediate Or Cancel
#     544             })
# --> 545         response = self.privatePostOrder(self.extend(order, params))
#     546         return {
#     547             'info': response,
#
# ~/anaconda3/envs/py36/lib/python3.6/site-packages/ccxt/base/exchange.py in extend(*args)
#     463                 result = {}
#     464             for arg in args:
# --> 465                 result.update(arg)
#     466             return result
#     467         return {}
#
# TypeError: 'NoneType' object is not iterable

# %%
# Example market sell
res = exchange.create_market_sell_order(asset, 20)
pprint(res)
# Out:
# {'id': '19123522',
#  'info': {'clientOrderId': 'XplE01gtT5Oepyb7CpT3Qw',
#           'executedQty': '20.00000000',
#           'orderId': 19123522,
#           'origQty': '20.00000000',
#           'price': '0.00000000',
#           'side': 'SELL',
#           'status': 'FILLED',
#           'symbol': 'XRPBTC',
#           'timeInForce': 'GTC',
#           'transactTime': 1516168063192,
#           'type': 'MARKET'}}

# %%
# Example market buy - doesnt require as much of the asset
res = exchange.create_market_buy_order(asset, 10)
pprint(res)
# Out:
# {'id': '19123922',
#  'info': {'clientOrderId': 'AirnAOarZeKa39YGear9hh',
#           'executedQty': '10.00000000',
#           'orderId': 19123922,
#           'origQty': '10.00000000',
#           'price': '0.00000000',
#           'side': 'BUY',
#           'status': 'FILLED',
#           'symbol': 'XRPBTC',
#           'timeInForce': 'GTC',
#           'transactTime': 1516168163119,
#           'type': 'MARKET'}}

# %%
# Selling the previous order's purchase
res = exchange.create_market_sell_order(asset, 10)
pprint(res)
# Out:
# {'id': '19124112',
#  'info': {'clientOrderId': 'n9zQ7MXdjGoKvLXks8m6D7',
#           'executedQty': '10.00000000',
#           'orderId': 19124112,
#           'origQty': '10.00000000',
#           'price': '0.00000000',
#           'side': 'SELL',
#           'status': 'FILLED',
#           'symbol': 'XRPBTC',
#           'timeInForce': 'GTC',
#           'transactTime': 1516168224548,
#           'type': 'MARKET'}}

# %%
# Example of how to get amount to lots for exchanges
pprint(exchange.client.amount_to_lots(asset.symbol, quantity))
# Out:
# 9.0

# %%
# Example order book data
pprint(exchange.fetch_order_book(asset))
# Out:
# {'asks': [[0.00010365, 61.0],
#           [0.00010366, 394.0],
#           [0.0001037, 170.0],
#           [0.00010373, 471.0],
#           [0.00010374, 203.0],
#           [0.00010375, 462.0],
#           [0.0001038, 710.0],
#           [0.00010384, 319.0],
#           [0.00010385, 89.0],
#           [0.00010388, 882.0],
#           [0.00010389, 120.0],
#           [0.0001039, 1316.0],
#           [0.00010392, 900.0],
#           [0.00010394, 700.0],
#           [0.000104, 20407.0],
#           [0.00010405, 70.0],
#           [0.00010409, 520.0],
#           [0.00010411, 100.0],
#           [0.00010412, 80.0],
#           [0.00010415, 30.0],
#           [0.0001042, 60.0],
#           [0.00010438, 71.0],
#           [0.00010439, 60.0],
#           [0.00010446, 1458.0],
#           [0.00010447, 90.0],
#           [0.00010448, 20.0],
#           [0.00010449, 247.0],
#           [0.0001045, 10256.0],
#           [0.00010451, 274.0],
#           [0.00010453, 210.0],
#           [0.00010455, 170.0],
#           [0.00010456, 20.0],
#           [0.00010457, 160.0],
#           [0.0001047, 238.0],
#           [0.00010479, 707.0],
#           [0.0001048, 22481.0],
#           [0.00010486, 27.0],
#           [0.0001049, 157.0],
#           [0.00010495, 156.0],
#           [0.00010499, 120.0],
#           [0.000105, 17372.0],
#           [0.00010501, 480.0],
#           [0.00010503, 352.0],
#           [0.00010506, 1028.0],
#           [0.00010511, 665.0],
#           [0.00010516, 30.0],
#           [0.00010522, 2000.0],
#           [0.00010525, 17772.0],
#           [0.0001053, 201.0],
#           [0.00010534, 84.0],
#           [0.0001054, 29.0],
#           [0.0001055, 1164.0],
#           [0.00010561, 2800.0],
#           [0.0001058, 50.0],
#           [0.0001059, 150.0],
#           [0.00010598, 478.0],
#           [0.00010599, 300.0],
#           [0.000106, 8879.0],
#           [0.00010603, 94.0],
#           [0.00010618, 389.0],
#           [0.00010621, 1649.0],
#           [0.00010623, 28.0],
#           [0.00010625, 74710.0],
#           [0.00010627, 318.0],
#           [0.00010628, 20.0],
#           [0.00010629, 50.0],
#           [0.00010634, 9504.0],
#           [0.00010637, 31.0],
#           [0.00010638, 40.0],
#           [0.0001064, 336.0],
#           [0.00010643, 489.0],
#           [0.00010645, 526.0],
#           [0.00010647, 20.0],
#           [0.0001065, 1238.0],
#           [0.00010651, 30.0],
#           [0.00010653, 910.0],
#           [0.00010659, 671.0],
#           [0.00010665, 20.0],
#           [0.00010666, 60.0],
#           [0.0001067, 47.0],
#           [0.00010672, 677.0],
#           [0.0001068, 100.0],
#           [0.00010685, 500.0],
#           [0.00010688, 20.0],
#           [0.0001069, 20.0],
#           [0.00010695, 3924.0],
#           [0.00010696, 136.0],
#           [0.00010699, 1390.0],
#           [0.000107, 16024.0],
#           [0.00010701, 838.0],
#           [0.00010703, 93.0],
#           [0.00010711, 137.0],
#           [0.00010727, 238.0],
#           [0.0001074, 1160.0],
#           [0.00010743, 30.0],
#           [0.00010745, 790.0],
#           [0.00010749, 30.0],
#           [0.0001075, 4342.0],
#           [0.00010751, 132.0],
#           [0.00010755, 268.0]],
#  'bids': [[0.00010358, 1464.0],
#           [0.00010353, 763.0],
#           [0.00010352, 17212.0],
#           [0.00010351, 248.0],
#           [0.0001035, 59776.0],
#           [0.00010349, 210.0],
#           [0.00010346, 660.0],
#           [0.00010345, 2452.0],
#           [0.0001034, 705.0],
#           [0.00010338, 40.0],
#           [0.0001033, 105.0],
#           [0.00010326, 728.0],
#           [0.00010325, 40.0],
#           [0.00010314, 1021.0],
#           [0.00010313, 891.0],
#           [0.00010312, 5022.0],
#           [0.00010309, 34759.0],
#           [0.000103, 608.0],
#           [0.00010299, 158.0],
#           [0.00010294, 951.0],
#           [0.0001029, 1298.0],
#           [0.00010287, 932.0],
#           [0.00010277, 2623.0],
#           [0.00010276, 25.0],
#           [0.00010273, 4000.0],
#           [0.00010271, 44.0],
#           [0.00010269, 49.0],
#           [0.00010267, 102.0],
#           [0.00010261, 148.0],
#           [0.00010257, 120.0],
#           [0.00010256, 161.0],
#           [0.00010254, 301.0],
#           [0.00010251, 527.0],
#           [0.0001025, 1898.0],
#           [0.00010242, 976.0],
#           [0.00010236, 116.0],
#           [0.00010234, 20.0],
#           [0.00010232, 199.0],
#           [0.0001023, 1204.0],
#           [0.00010222, 500.0],
#           [0.0001022, 1800.0],
#           [0.00010214, 35.0],
#           [0.00010213, 2771.0],
#           [0.00010209, 179.0],
#           [0.00010205, 1012.0],
#           [0.00010204, 4817.0],
#           [0.00010203, 657.0],
#           [0.00010201, 200.0],
#           [0.000102, 6684.0],
#           [0.00010199, 180.0],
#           [0.00010192, 9811.0],
#           [0.00010191, 1274.0],
#           [0.0001019, 2106.0],
#           [0.00010186, 3487.0],
#           [0.00010185, 3260.0],
#           [0.0001018, 168.0],
#           [0.00010179, 21.0],
#           [0.00010175, 256.0],
#           [0.0001017, 13128.0],
#           [0.00010168, 20.0],
#           [0.00010167, 120.0],
#           [0.00010166, 55.0],
#           [0.00010161, 1233.0],
#           [0.0001016, 6108.0],
#           [0.00010159, 341.0],
#           [0.00010152, 1491.0],
#           [0.0001015, 1662.0],
#           [0.00010146, 843.0],
#           [0.0001014, 5100.0],
#           [0.00010138, 79.0],
#           [0.00010137, 995.0],
#           [0.00010135, 311.0],
#           [0.0001013, 20.0],
#           [0.00010127, 14797.0],
#           [0.00010123, 644.0],
#           [0.00010122, 225.0],
#           [0.0001012, 1240.0],
#           [0.00010118, 343.0],
#           [0.00010117, 3255.0],
#           [0.00010116, 450.0],
#           [0.00010114, 500.0],
#           [0.00010111, 375.0],
#           [0.0001011, 880.0],
#           [0.00010107, 20.0],
#           [0.00010103, 50.0],
#           [0.00010101, 488.0],
#           [0.000101, 11516.0],
#           [0.00010095, 308.0],
#           [0.00010094, 30.0],
#           [0.00010091, 829.0],
#           [0.0001009, 1317.0],
#           [0.00010083, 168.0],
#           [0.00010082, 22.0],
#           [0.00010081, 12974.0],
#           [0.00010076, 1133.0],
#           [0.00010074, 73.0],
#           [0.00010068, 1333.0],
#           [0.00010067, 23.0],
#           [0.00010063, 200.0],
#           [0.0001006, 356.0]],
#  'datetime': '2018-01-17T05:55:49.204Z',
#  'timestamp': 1516168549204}

# %%
# Example balance
pprint(exchange.fetch_balance())
# Out:
# {
#     "BTC": {
#         "free": 0.03307423,
#         "used": 0.0,
#         "total": 0.03307423
#     },
#     "LTC": {
#         "free": 0.0,
#         "used": 0.0,
#         "total": 0.0
#     },
#     "ETH": {
#         "free": 0.0,
#         "used": 0.0,
#         "total": 0.0
#     },
#     "BNC": {
#         "free": 0.0,
#         "used": 0.0,
#         "total": 0.0
#     },
#     "ICO": {
#         "free": 0.0,
#         "used": 0.0,
#         "total": 0.0
#     },
#     "NEO": {
#         "free": 0.0,
#         "used": 0.0,
#         "total": 0.0
#     },
#     "BNB": {
#         "free": 0.0,
#         "used": 0.0,
#         "total": 0.0
#     },
#     "123": {
#         "free": 0.0,
#         "used": 0.0,
#         "total": 0.0
#     },
#     "456": {
#         "free": 0.0,
#         "used": 0.0,
#         "total": 0.0
#     },
#     "QTUM": {
#         "free": 0.0,
#         "used": 0.0,
#         "total": 0.0
#     },
#     "EOS": {
#         "free": 0.0,
#         "used": 0.0,
#         "total": 0.0
#     },
#     "SNT": {
#         "free": 0.0,
#         "used": 0.0,
#         "total": 0.0
#     },
#     "BNT": {
#         "free": 0.0,
#         "used": 0.0,
#         "total": 0.0
#     },
#     "GAS": {
#         "free": 0.0,
#         "used": 0.0,
#         "total": 0.0
#     },
#     "BCH": {
#         "free": 0.0,
#         "used": 0.0,
#         "total": 0.0
#     },
#     "BTM": {
#         "free": 0.0,
#         "used": 0.0,
#         "total": 0.0
#     },
#     "USDT": {
#         "free": 0.0,
#         "used": 0.0,
#         "total": 0.0
#     },
#     "HCC": {
#         "free": 0.0,
#         "used": 0.0,
#         "total": 0.0
#     },
#     "HSR": {
#         "free": 0.0,
#         "used": 0.0,
#         "total": 0.0
#     },
#     "OAX": {
#         "free": 0.0,
#         "used": 0.0,
#         "total": 0.0
#     },
#     "DNT": {
#         "free": 0.0,
#         "used": 0.0,
#         "total": 0.0
#     },
#     "MCO": {
#         "free": 0.0,
#         "used": 0.0,
#         "total": 0.0
#     },
#     "ICN": {
#         "free": 0.0,
#         "used": 0.0,
#         "total": 0.0
#     },
#     "ELC": {
#         "free": 0.0,
#         "used": 0.0,
#         "total": 0.0
#     },
#     "PAY": {
#         "free": 0.0,
#         "used": 0.0,
#         "total": 0.0
#     },
#     "ZRX": {
#         "free": 0.0,
#         "used": 0.0,
#         "total": 0.0
#     },
#     "OMG": {
#         "free": 0.0,
#         "used": 0.0,
#         "total": 0.0
#     },
#     "WTC": {
#         "free": 0.0,
#         "used": 0.0,
#         "total": 0.0
#     },
#     "LRX": {
#         "free": 0.0,
#         "used": 0.0,
#         "total": 0.0
#     },
#     "YOYO": {
#         "free": 0.0,
#         "used": 0.0,
#         "total": 0.0
#     },
#     "LRC": {
#         "free": 0.0,
#         "used": 0.0,
#         "total": 0.0
#     },
#     "LLT": {
#         "free": 0.0,
#         "used": 0.0,
#         "total": 0.0
#     },
#     "TRX": {
#         "free": 0.0,
#         "used": 0.0,
#         "total": 0.0
#     },
#     "FID": {
#         "free": 0.0,
#         "used": 0.0,
#         "total": 0.0
#     },
#     "SNGLS": {
#         "free": 0.0,
#         "used": 0.0,
#         "total": 0.0
#     },
#     "STRAT": {
#         "free": 0.0,
#         "used": 0.0,
#         "total": 0.0
#     },
#     "BQX": {
#         "free": 0.0,
#         "used": 0.0,
#         "total": 0.0
#     },
#     "FUN": {
#         "free": 0.0,
#         "used": 0.0,
#         "total": 0.0
#     },
#     "KNC": {
#         "free": 0.0,
#         "used": 0.0,
#         "total": 0.0
#     },
#     "CDT": {
#         "free": 0.0,
#         "used": 0.0,
#         "total": 0.0
#     },
#     "XVG": {
#         "free": 0.0,
#         "used": 0.0,
#         "total": 0.0
#     },
#     "IOTA": {
#         "free": 0.0,
#         "used": 0.0,
#         "total": 0.0
#     },
#     "SNM": {
#         "free": 0.0,
#         "used": 0.0,
#         "total": 0.0
#     },
#     "LINK": {
#         "free": 0.0,
#         "used": 0.0,
#         "total": 0.0
#     },
#     "CVC": {
#         "free": 0.0,
#         "used": 0.0,
#         "total": 0.0
#     },
#     "TNT": {
#         "free": 0.0,
#         "used": 0.0,
#         "total": 0.0
#     },
#     "REP": {
#         "free": 0.0,
#         "used": 0.0,
#         "total": 0.0
#     },
#     "CTR": {
#         "free": 0.0,
#         "used": 0.0,
#         "total": 0.0
#     },
#     "MDA": {
#         "free": 0.0,
#         "used": 0.0,
#         "total": 0.0
#     },
#     "MTL": {
#         "free": 0.0,
#         "used": 0.0,
#         "total": 0.0
#     },
#     "SALT": {
#         "free": 0.0,
#         "used": 0.0,
#         "total": 0.0
#     },
#     "NULS": {
#         "free": 0.0,
#         "used": 0.0,
#         "total": 0.0
#     },
#     "SUB": {
#         "free": 0.0,
#         "used": 0.0,
#         "total": 0.0
#     },
#     "STX": {
#         "free": 0.0,
#         "used": 0.0,
#         "total": 0.0
#     },
#     "MTH": {
#         "free": 0.0,
#         "used": 0.0,
#         "total": 0.0
#     },
#     "CAT": {
#         "free": 0.0,
#         "used": 0.0,
#         "total": 0.0
#     },
#     "ADX": {
#         "free": 0.0,
#         "used": 0.0,
#         "total": 0.0
#     },
#     "PIX": {
#         "free": 0.0,
#         "used": 0.0,
#         "total": 0.0
#     },
#     "ETC": {
#         "free": 0.0,
#         "used": 0.0,
#         "total": 0.0
#     },
#     "ENG": {
#         "free": 0.0,
#         "used": 0.0,
#         "total": 0.0
#     },
#     "ZEC": {
#         "free": 0.0,
#         "used": 0.0,
#         "total": 0.0
#     },
#     "AST": {
#         "free": 0.0,
#         "used": 0.0,
#         "total": 0.0
#     },
#     "1ST": {
#         "free": 0.0,
#         "used": 0.0,
#         "total": 0.0
#     },
#     "GNT": {
#         "free": 0.0,
#         "used": 0.0,
#         "total": 0.0
#     },
#     "DGD": {
#         "free": 0.0,
#         "used": 0.0,
#         "total": 0.0
#     },
#     "BAT": {
#         "free": 0.0,
#         "used": 0.0,
#         "total": 0.0
#     },
#     "DASH": {
#         "free": 0.0,
#         "used": 0.0,
#         "total": 0.0
#     },
#     "POWR": {
#         "free": 0.0,
#         "used": 0.0,
#         "total": 0.0
#     },
#     "BTG": {
#         "free": 0.0,
#         "used": 0.0,
#         "total": 0.0
#     },
#     "REQ": {
#         "free": 0.0,
#         "used": 0.0,
#         "total": 0.0
#     },
#     "XMR": {
#         "free": 0.0,
#         "used": 0.0,
#         "total": 0.0
#     },
#     "EVX": {
#         "free": 0.0,
#         "used": 0.0,
#         "total": 0.0
#     },
#     "VIB": {
#         "free": 0.0,
#         "used": 0.0,
#         "total": 0.0
#     },
#     "ENJ": {
#         "free": 0.0,
#         "used": 0.0,
#         "total": 0.0
#     },
#     "VEN": {
#         "free": 0.0,
#         "used": 0.0,
#         "total": 0.0
#     },
#     "CAG": {
#         "free": 0.0,
#         "used": 0.0,
#         "total": 0.0
#     },
#     "EDG": {
#         "free": 0.0,
#         "used": 0.0,
#         "total": 0.0
#     },
#     "ARK": {
#         "free": 0.0,
#         "used": 0.0,
#         "total": 0.0
#     },
#     "XRP": {
#         "free": 4.965,
#         "used": 0.0,
#         "total": 4.965
#     },
#     "MOD": {
#         "free": 0.0,
#         "used": 0.0,
#         "total": 0.0
#     },
#     "AVT": {
#         "free": 0.0,
#         "used": 0.0,
#         "total": 0.0
#     },
#     "STORJ": {
#         "free": 0.0,
#         "used": 0.0,
#         "total": 0.0
#     },
#     "KMD": {
#         "free": 0.0,
#         "used": 0.0,
#         "total": 0.0
#     },
#     "RCN": {
#         "free": 0.0,
#         "used": 0.0,
#         "total": 0.0
#     },
#     "EDO": {
#         "free": 0.0,
#         "used": 0.0,
#         "total": 0.0
#     },
#     "QASH": {
#         "free": 0.0,
#         "used": 0.0,
#         "total": 0.0
#     },
#     "SAN": {
#         "free": 0.0,
#         "used": 0.0,
#         "total": 0.0
#     },
#     "DATA": {
#         "free": 0.0,
#         "used": 0.0,
#         "total": 0.0
#     },
#     "DLT": {
#         "free": 0.0,
#         "used": 0.0,
#         "total": 0.0
#     },
#     "GUP": {
#         "free": 0.0,
#         "used": 0.0,
#         "total": 0.0
#     },
#     "MCAP": {
#         "free": 0.0,
#         "used": 0.0,
#         "total": 0.0
#     },
#     "MANA": {
#         "free": 0.0,
#         "used": 0.0,
#         "total": 0.0
#     },
#     "PPT": {
#         "free": 0.0,
#         "used": 0.0,
#         "total": 0.0
#     },
#     "OTN": {
#         "free": 0.0,
#         "used": 0.0,
#         "total": 0.0
#     },
#     "CFD": {
#         "free": 0.0,
#         "used": 0.0,
#         "total": 0.0
#     },
#     "RDN": {
#         "free": 0.0,
#         "used": 0.0,
#         "total": 0.0
#     },
#     "GXS": {
#         "free": 0.0,
#         "used": 0.0,
#         "total": 0.0
#     },
#     "AMB": {
#         "free": 0.0,
#         "used": 0.0,
#         "total": 0.0
#     },
#     "ARN": {
#         "free": 0.0,
#         "used": 0.0,
#         "total": 0.0
#     },
#     "BCPT": {
#         "free": 0.0,
#         "used": 0.0,
#         "total": 0.0
#     },
#     "CND": {
#         "free": 0.0,
#         "used": 0.0,
#         "total": 0.0
#     },
#     "GVT": {
#         "free": 0.0,
#         "used": 0.0,
#         "total": 0.0
#     },
#     "POE": {
#         "free": 0.0,
#         "used": 0.0,
#         "total": 0.0
#     },
#     "ALIS": {
#         "free": 0.0,
#         "used": 0.0,
#         "total": 0.0
#     },
#     "BTS": {
#         "free": 0.996,
#         "used": 0.0,
#         "total": 0.996
#     },
#     "FUEL": {
#         "free": 0.0,
#         "used": 0.0,
#         "total": 0.0
#     },
#     "XZC": {
#         "free": 0.0,
#         "used": 0.0,
#         "total": 0.0
#     },
#     "QSP": {
#         "free": 0.0,
#         "used": 0.0,
#         "total": 0.0
#     },
#     "LSK": {
#         "free": 0.0,
#         "used": 0.0,
#         "total": 0.0
#     },
#     "BCD": {
#         "free": 0.0,
#         "used": 0.0,
#         "total": 0.0
#     },
#     "TNB": {
#         "free": 0.0,
#         "used": 0.0,
#         "total": 0.0
#     },
#     "GRX": {
#         "free": 0.0,
#         "used": 0.0,
#         "total": 0.0
#     },
#     "STAR": {
#         "free": 0.0,
#         "used": 0.0,
#         "total": 0.0
#     },
#     "ADA": {
#         "free": 0.0,
#         "used": 0.0,
#         "total": 0.0
#     },
#     "LEND": {
#         "free": 0.0,
#         "used": 0.0,
#         "total": 0.0
#     },
#     "IFT": {
#         "free": 0.0,
#         "used": 0.0,
#         "total": 0.0
#     },
#     "KICK": {
#         "free": 0.0,
#         "used": 0.0,
#         "total": 0.0
#     },
#     "UKG": {
#         "free": 0.0,
#         "used": 0.0,
#         "total": 0.0
#     },
#     "VOISE": {
#         "free": 0.0,
#         "used": 0.0,
#         "total": 0.0
#     },
#     "XLM": {
#         "free": 0.0,
#         "used": 0.0,
#         "total": 0.0
#     },
#     "CMT": {
#         "free": 0.0,
#         "used": 0.0,
#         "total": 0.0
#     },
#     "WAVES": {
#         "free": 0.0,
#         "used": 0.0,
#         "total": 0.0
#     },
#     "WABI": {
#         "free": 0.0,
#         "used": 0.0,
#         "total": 0.0
#     },
#     "SBTC": {
#         "free": 0.0,
#         "used": 0.0,
#         "total": 0.0
#     },
#     "BCX": {
#         "free": 0.0,
#         "used": 0.0,
#         "total": 0.0
#     },
#     "GTO": {
#         "free": 0.0,
#         "used": 0.0,
#         "total": 0.0
#     },
#     "ETF": {
#         "free": 0.0,
#         "used": 0.0,
#         "total": 0.0
#     },
#     "ICX": {
#         "free": 0.0,
#         "used": 0.0,
#         "total": 0.0
#     },
#     "OST": {
#         "free": 0.0,
#         "used": 0.0,
#         "total": 0.0
#     },
#     "ELF": {
#         "free": 0.0,
#         "used": 0.0,
#         "total": 0.0
#     },
#     "AION": {
#         "free": 0.0,
#         "used": 0.0,
#         "total": 0.0
#     },
#     "WINGS": {
#         "free": 0.0,
#         "used": 0.0,
#         "total": 0.0
#     },
#     "BRD": {
#         "free": 0.0,
#         "used": 0.0,
#         "total": 0.0
#     },
#     "NEBL": {
#         "free": 0.0,
#         "used": 0.0,
#         "total": 0.0
#     },
#     "NAV": {
#         "free": 0.0,
#         "used": 0.0,
#         "total": 0.0
#     },
#     "VIBE": {
#         "free": 0.0,
#         "used": 0.0,
#         "total": 0.0
#     },
#     "LUN": {
#         "free": 0.0,
#         "used": 0.0,
#         "total": 0.0
#     },
#     "TRIG": {
#         "free": 0.0,
#         "used": 0.0,
#         "total": 0.0
#     },
#     "APPC": {
#         "free": 0.0,
#         "used": 0.0,
#         "total": 0.0
#     },
#     "CHAT": {
#         "free": 0.0,
#         "used": 0.0,
#         "total": 0.0
#     },
#     "RLC": {
#         "free": 0.0,
#         "used": 0.0,
#         "total": 0.0
#     },
#     "INS": {
#         "free": 0.0,
#         "used": 0.0,
#         "total": 0.0
#     },
#     "free": {
#         "BTC": 0.03307423,
#         "LTC": 0.0,
#         "ETH": 0.0,
#         "BNC": 0.0,
#         "ICO": 0.0,
#         "NEO": 0.0,
#         "BNB": 0.0,
#         "123": 0.0,
#         "456": 0.0,
#         "QTUM": 0.0,
#         "EOS": 0.0,
#         "SNT": 0.0,
#         "BNT": 0.0,
#         "GAS": 0.0,
#         "BCH": 0.0,
#         "BTM": 0.0,
#         "USDT": 0.0,
#         "HCC": 0.0,
#         "HSR": 0.0,
#         "OAX": 0.0,
#         "DNT": 0.0,
#         "MCO": 0.0,
#         "ICN": 0.0,
#         "ELC": 0.0,
#         "PAY": 0.0,
#         "ZRX": 0.0,
#         "OMG": 0.0,
#         "WTC": 0.0,
#         "LRX": 0.0,
#         "YOYO": 0.0,
#         "LRC": 0.0,
#         "LLT": 0.0,
#         "TRX": 0.0,
#         "FID": 0.0,
#         "SNGLS": 0.0,
#         "STRAT": 0.0,
#         "BQX": 0.0,
#         "FUN": 0.0,
#         "KNC": 0.0,
#         "CDT": 0.0,
#         "XVG": 0.0,
#         "IOTA": 0.0,
#         "SNM": 0.0,
#         "LINK": 0.0,
#         "CVC": 0.0,
#         "TNT": 0.0,
#         "REP": 0.0,
#         "CTR": 0.0,
#         "MDA": 0.0,
#         "MTL": 0.0,
#         "SALT": 0.0,
#         "NULS": 0.0,
#         "SUB": 0.0,
#         "STX": 0.0,
#         "MTH": 0.0,
#         "CAT": 0.0,
#         "ADX": 0.0,
#         "PIX": 0.0,
#         "ETC": 0.0,
#         "ENG": 0.0,
#         "ZEC": 0.0,
#         "AST": 0.0,
#         "1ST": 0.0,
#         "GNT": 0.0,
#         "DGD": 0.0,
#         "BAT": 0.0,
#         "DASH": 0.0,
#         "POWR": 0.0,
#         "BTG": 0.0,
#         "REQ": 0.0,
#         "XMR": 0.0,
#         "EVX": 0.0,
#         "VIB": 0.0,
#         "ENJ": 0.0,
#         "VEN": 0.0,
#         "CAG": 0.0,
#         "EDG": 0.0,
#         "ARK": 0.0,
#         "XRP": 4.965,
#         "MOD": 0.0,
#         "AVT": 0.0,
#         "STORJ": 0.0,
#         "KMD": 0.0,
#         "RCN": 0.0,
#         "EDO": 0.0,
#         "QASH": 0.0,
#         "SAN": 0.0,
#         "DATA": 0.0,
#         "DLT": 0.0,
#         "GUP": 0.0,
#         "MCAP": 0.0,
#         "MANA": 0.0,
#         "PPT": 0.0,
#         "OTN": 0.0,
#         "CFD": 0.0,
#         "RDN": 0.0,
#         "GXS": 0.0,
#         "AMB": 0.0,
#         "ARN": 0.0,
#         "BCPT": 0.0,
#         "CND": 0.0,
#         "GVT": 0.0,
#         "POE": 0.0,
#         "ALIS": 0.0,
#         "BTS": 0.996,
#         "FUEL": 0.0,
#         "XZC": 0.0,
#         "QSP": 0.0,
#         "LSK": 0.0,
#         "BCD": 0.0,
#         "TNB": 0.0,
#         "GRX": 0.0,
#         "STAR": 0.0,
#         "ADA": 0.0,
#         "LEND": 0.0,
#         "IFT": 0.0,
#         "KICK": 0.0,
#         "UKG": 0.0,
#         "VOISE": 0.0,
#         "XLM": 0.0,
#         "CMT": 0.0,
#         "WAVES": 0.0,
#         "WABI": 0.0,
#         "SBTC": 0.0,
#         "BCX": 0.0,
#         "GTO": 0.0,
#         "ETF": 0.0,
#         "ICX": 0.0,
#         "OST": 0.0,
#         "ELF": 0.0,
#         "AION": 0.0,
#         "WINGS": 0.0,
#         "BRD": 0.0,
#         "NEBL": 0.0,
#         "NAV": 0.0,
#         "VIBE": 0.0,
#         "LUN": 0.0,
#         "TRIG": 0.0,
#         "APPC": 0.0,
#         "CHAT": 0.0,
#         "RLC": 0.0,
#         "INS": 0.0
#     },
#     "used": {
#         "BTC": 0.0,
#         "LTC": 0.0,
#         "ETH": 0.0,
#         "BNC": 0.0,
#         "ICO": 0.0,
#         "NEO": 0.0,
#         "BNB": 0.0,
#         "123": 0.0,
#         "456": 0.0,
#         "QTUM": 0.0,
#         "EOS": 0.0,
#         "SNT": 0.0,
#         "BNT": 0.0,
#         "GAS": 0.0,
#         "BCH": 0.0,
#         "BTM": 0.0,
#         "USDT": 0.0,
#         "HCC": 0.0,
#         "HSR": 0.0,
#         "OAX": 0.0,
#         "DNT": 0.0,
#         "MCO": 0.0,
#         "ICN": 0.0,
#         "ELC": 0.0,
#         "PAY": 0.0,
#         "ZRX": 0.0,
#         "OMG": 0.0,
#         "WTC": 0.0,
#         "LRX": 0.0,
#         "YOYO": 0.0,
#         "LRC": 0.0,
#         "LLT": 0.0,
#         "TRX": 0.0,
#         "FID": 0.0,
#         "SNGLS": 0.0,
#         "STRAT": 0.0,
#         "BQX": 0.0,
#         "FUN": 0.0,
#         "KNC": 0.0,
#         "CDT": 0.0,
#         "XVG": 0.0,
#         "IOTA": 0.0,
#         "SNM": 0.0,
#         "LINK": 0.0,
#         "CVC": 0.0,
#         "TNT": 0.0,
#         "REP": 0.0,
#         "CTR": 0.0,
#         "MDA": 0.0,
#         "MTL": 0.0,
#         "SALT": 0.0,
#         "NULS": 0.0,
#         "SUB": 0.0,
#         "STX": 0.0,
#         "MTH": 0.0,
#         "CAT": 0.0,
#         "ADX": 0.0,
#         "PIX": 0.0,
#         "ETC": 0.0,
#         "ENG": 0.0,
#         "ZEC": 0.0,
#         "AST": 0.0,
#         "1ST": 0.0,
#         "GNT": 0.0,
#         "DGD": 0.0,
#         "BAT": 0.0,
#         "DASH": 0.0,
#         "POWR": 0.0,
#         "BTG": 0.0,
#         "REQ": 0.0,
#         "XMR": 0.0,
#         "EVX": 0.0,
#         "VIB": 0.0,
#         "ENJ": 0.0,
#         "VEN": 0.0,
#         "CAG": 0.0,
#         "EDG": 0.0,
#         "ARK": 0.0,
#         "XRP": 0.0,
#         "MOD": 0.0,
#         "AVT": 0.0,
#         "STORJ": 0.0,
#         "KMD": 0.0,
#         "RCN": 0.0,
#         "EDO": 0.0,
#         "QASH": 0.0,
#         "SAN": 0.0,
#         "DATA": 0.0,
#         "DLT": 0.0,
#         "GUP": 0.0,
#         "MCAP": 0.0,
#         "MANA": 0.0,
#         "PPT": 0.0,
#         "OTN": 0.0,
#         "CFD": 0.0,
#         "RDN": 0.0,
#         "GXS": 0.0,
#         "AMB": 0.0,
#         "ARN": 0.0,
#         "BCPT": 0.0,
#         "CND": 0.0,
#         "GVT": 0.0,
#         "POE": 0.0,
#         "ALIS": 0.0,
#         "BTS": 0.0,
#         "FUEL": 0.0,
#         "XZC": 0.0,
#         "QSP": 0.0,
#         "LSK": 0.0,
#         "BCD": 0.0,
#         "TNB": 0.0,
#         "GRX": 0.0,
#         "STAR": 0.0,
#         "ADA": 0.0,
#         "LEND": 0.0,
#         "IFT": 0.0,
#         "KICK": 0.0,
#         "UKG": 0.0,
#         "VOISE": 0.0,
#         "XLM": 0.0,
#         "CMT": 0.0,
#         "WAVES": 0.0,
#         "WABI": 0.0,
#         "SBTC": 0.0,
#         "BCX": 0.0,
#         "GTO": 0.0,
#         "ETF": 0.0,
#         "ICX": 0.0,
#         "OST": 0.0,
#         "ELF": 0.0,
#         "AION": 0.0,
#         "WINGS": 0.0,
#         "BRD": 0.0,
#         "NEBL": 0.0,
#         "NAV": 0.0,
#         "VIBE": 0.0,
#         "LUN": 0.0,
#         "TRIG": 0.0,
#         "APPC": 0.0,
#         "CHAT": 0.0,
#         "RLC": 0.0,
#         "INS": 0.0
#     },
#     "total": {
#         "BTC": 0.03307423,
#         "LTC": 0.0,
#         "ETH": 0.0,
#         "BNC": 0.0,
#         "ICO": 0.0,
#         "NEO": 0.0,
#         "BNB": 0.0,
#         "123": 0.0,
#         "456": 0.0,
#         "QTUM": 0.0,
#         "EOS": 0.0,
#         "SNT": 0.0,
#         "BNT": 0.0,
#         "GAS": 0.0,
#         "BCH": 0.0,
#         "BTM": 0.0,
#         "USDT": 0.0,
#         "HCC": 0.0,
#         "HSR": 0.0,
#         "OAX": 0.0,
#         "DNT": 0.0,
#         "MCO": 0.0,
#         "ICN": 0.0,
#         "ELC": 0.0,
#         "PAY": 0.0,
#         "ZRX": 0.0,
#         "OMG": 0.0,
#         "WTC": 0.0,
#         "LRX": 0.0,
#         "YOYO": 0.0,
#         "LRC": 0.0,
#         "LLT": 0.0,
#         "TRX": 0.0,
#         "FID": 0.0,
#         "SNGLS": 0.0,
#         "STRAT": 0.0,
#         "BQX": 0.0,
#         "FUN": 0.0,
#         "KNC": 0.0,
#         "CDT": 0.0,
#         "XVG": 0.0,
#         "IOTA": 0.0,
#         "SNM": 0.0,
#         "LINK": 0.0,
#         "CVC": 0.0,
#         "TNT": 0.0,
#         "REP": 0.0,
#         "CTR": 0.0,
#         "MDA": 0.0,
#         "MTL": 0.0,
#         "SALT": 0.0,
#         "NULS": 0.0,
#         "SUB": 0.0,
#         "STX": 0.0,
#         "MTH": 0.0,
#         "CAT": 0.0,
#         "ADX": 0.0,
#         "PIX": 0.0,
#         "ETC": 0.0,
#         "ENG": 0.0,
#         "ZEC": 0.0,
#         "AST": 0.0,
#         "1ST": 0.0,
#         "GNT": 0.0,
#         "DGD": 0.0,
#         "BAT": 0.0,
#         "DASH": 0.0,
#         "POWR": 0.0,
#         "BTG": 0.0,
#         "REQ": 0.0,
#         "XMR": 0.0,
#         "EVX": 0.0,
#         "VIB": 0.0,
#         "ENJ": 0.0,
#         "VEN": 0.0,
#         "CAG": 0.0,
#         "EDG": 0.0,
#         "ARK": 0.0,
#         "XRP": 4.965,
#         "MOD": 0.0,
#         "AVT": 0.0,
#         "STORJ": 0.0,
#         "KMD": 0.0,
#         "RCN": 0.0,
#         "EDO": 0.0,
#         "QASH": 0.0,
#         "SAN": 0.0,
#         "DATA": 0.0,
#         "DLT": 0.0,
#         "GUP": 0.0,
#         "MCAP": 0.0,
#         "MANA": 0.0,
#         "PPT": 0.0,
#         "OTN": 0.0,
#         "CFD": 0.0,
#         "RDN": 0.0,
#         "GXS": 0.0,
#         "AMB": 0.0,
#         "ARN": 0.0,
#         "BCPT": 0.0,
#         "CND": 0.0,
#         "GVT": 0.0,
#         "POE": 0.0,
#         "ALIS": 0.0,
#         "BTS": 0.996,
#         "FUEL": 0.0,
#         "XZC": 0.0,
#         "QSP": 0.0,
#         "LSK": 0.0,
#         "BCD": 0.0,
#         "TNB": 0.0,
#         "GRX": 0.0,
#         "STAR": 0.0,
#         "ADA": 0.0,
#         "LEND": 0.0,
#         "IFT": 0.0,
#         "KICK": 0.0,
#         "UKG": 0.0,
#         "VOISE": 0.0,
#         "XLM": 0.0,
#         "CMT": 0.0,
#         "WAVES": 0.0,
#         "WABI": 0.0,
#         "SBTC": 0.0,
#         "BCX": 0.0,
#         "GTO": 0.0,
#         "ETF": 0.0,
#         "ICX": 0.0,
#         "OST": 0.0,
#         "ELF": 0.0,
#         "AION": 0.0,
#         "WINGS": 0.0,
#         "BRD": 0.0,
#         "NEBL": 0.0,
#         "NAV": 0.0,
#         "VIBE": 0.0,
#         "LUN": 0.0,
#         "TRIG": 0.0,
#         "APPC": 0.0,
#         "CHAT": 0.0,
#         "RLC": 0.0,
#         "INS": 0.0
#     }
# }

# %%
# Example fetch order by id
# pprint(exchange.fetch_order(19121540, asset.symbol))
# Out:
# {'amount': 20.0,
#  'cost': 0.0020442,
#  'datetime': '2018-01-17T05:40:05.841Z',
#  'fee': None,
#  'filled': 20.0,
#  'id': '19121540',
#  'info': {'clientOrderId': 'XcRu3uVEd3fg4V657P6Tq2',
#           'executedQty': '20.00000000',
#           'icebergQty': '0.00000000',
#           'isWorking': True,
#           'orderId': 19121540,
#           'origQty': '20.00000000',
#           'price': '0.00010221',
#           'side': 'BUY',
#           'status': 'FILLED',
#           'stopPrice': '0.00000000',
#           'symbol': 'XRPBTC',
#           'time': 1516167604841,
#           'timeInForce': 'GTC',
#           'type': 'LIMIT'},
#  'price': 0.00010221,
#  'remaining': 0.0,
#  'side': 'buy',
#  'status': 'closed',
#  'symbol': 'XRP/BTC',
#  'timestamp': 1516167604841,
#  'type': 'limit'}

# %%
# Example fetch order
pprint(exchange.fetch_orders(asset))
# Out:
# [{'amount': 5.0,
#   'cost': 0.001078,
#   'datetime': '2018-01-04T22:20:38.781Z',
#   'fee': None,
#   'filled': 5.0,
#   'id': '13116770',
#   'info': {'clientOrderId': '0w1JD4gMu96LCJ6jlhVVV6',
#            'executedQty': '5.00000000',
#            'icebergQty': '0.00000000',
#            'isWorking': True,
#            'orderId': 13116770,
#            'origQty': '5.00000000',
#            'price': '0.00021560',
#            'side': 'BUY',
#            'status': 'FILLED',
#            'stopPrice': '0.00000000',
#            'symbol': 'XRPBTC',
#            'time': 1515104437781,
#            'timeInForce': 'GTC',
#            'type': 'LIMIT'},
#   'price': 0.0002156,
#   'remaining': 0.0,
#   'side': 'buy',
#   'status': 'closed',
#   'symbol': 'XRP/BTC',
#   'timestamp': 1515104437781,
#   'type': 'limit'},
#  {'amount': 20.0,
#   'cost': 0.0020442,
#   'datetime': '2018-01-17T05:40:05.841Z',
#   'fee': None,
#   'filled': 20.0,
#   'id': '19121540',
#   'info': {'clientOrderId': 'XcRu3uVEd3fg4V657P6Tq2',
#            'executedQty': '20.00000000',
#            'icebergQty': '0.00000000',
#            'isWorking': True,
#            'orderId': 19121540,
#            'origQty': '20.00000000',
#            'price': '0.00010221',
#            'side': 'BUY',
#            'status': 'FILLED',
#            'stopPrice': '0.00000000',
#            'symbol': 'XRPBTC',
#            'time': 1516167604841,
#            'timeInForce': 'GTC',
#            'type': 'LIMIT'},
#   'price': 0.00010221,
#   'remaining': 0.0,
#   'side': 'buy',
#   'status': 'closed',
#   'symbol': 'XRP/BTC',
#   'timestamp': 1516167604841,
#   'type': 'limit'},
#  {'amount': 20.0,
#   'cost': 0.0,
#   'datetime': '2018-01-17T05:47:43.192Z',
#   'fee': None,
#   'filled': 20.0,
#   'id': '19123522',
#   'info': {'clientOrderId': 'XplE01gtT5Oepyb7CpT3Qw',
#            'executedQty': '20.00000000',
#            'icebergQty': '0.00000000',
#            'isWorking': True,
#            'orderId': 19123522,
#            'origQty': '20.00000000',
#            'price': '0.00000000',
#            'side': 'SELL',
#            'status': 'FILLED',
#            'stopPrice': '0.00000000',
#            'symbol': 'XRPBTC',
#            'time': 1516168063192,
#            'timeInForce': 'GTC',
#            'type': 'MARKET'},
#   'price': 0.0,
#   'remaining': 0.0,
#   'side': 'sell',
#   'status': 'closed',
#   'symbol': 'XRP/BTC',
#   'timestamp': 1516168063192,
#   'type': 'market'},
#  {'amount': 10.0,
#   'cost': 0.0,
#   'datetime': '2018-01-17T05:49:23.119Z',
#   'fee': None,
#   'filled': 10.0,
#   'id': '19123922',
#   'info': {'clientOrderId': 'AirnAOarZeKa39YGear9hh',
#            'executedQty': '10.00000000',
#            'icebergQty': '0.00000000',
#            'isWorking': True,
#            'orderId': 19123922,
#            'origQty': '10.00000000',
#            'price': '0.00000000',
#            'side': 'BUY',
#            'status': 'FILLED',
#            'stopPrice': '0.00000000',
#            'symbol': 'XRPBTC',
#            'time': 1516168163119,
#            'timeInForce': 'GTC',
#            'type': 'MARKET'},
#   'price': 0.0,
#   'remaining': 0.0,
#   'side': 'buy',
#   'status': 'closed',
#   'symbol': 'XRP/BTC',
#   'timestamp': 1516168163119,
#   'type': 'market'},
#  {'amount': 10.0,
#   'cost': 0.0,
#   'datetime': '2018-01-17T05:50:25.548Z',
#   'fee': None,
#   'filled': 10.0,
#   'id': '19124112',
#   'info': {'clientOrderId': 'n9zQ7MXdjGoKvLXks8m6D7',
#            'executedQty': '10.00000000',
#            'icebergQty': '0.00000000',
#            'isWorking': True,
#            'orderId': 19124112,
#            'origQty': '10.00000000',
#            'price': '0.00000000',
#            'side': 'SELL',
#            'status': 'FILLED',
#            'stopPrice': '0.00000000',
#            'symbol': 'XRPBTC',
#            'time': 1516168224548,
#            'timeInForce': 'GTC',
#            'type': 'MARKET'},
#   'price': 0.0,
#   'remaining': 0.0,
#   'side': 'sell',
#   'status': 'closed',
#   'symbol': 'XRP/BTC',
#   'timestamp': 1516168224548,
#   'type': 'market'}]
